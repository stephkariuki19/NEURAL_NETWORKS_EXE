# %% [markdown]
# <a href="https://colab.research.google.com/github/stephkariuki19/NEURAL_NETWORKS_EXE/blob/main/Neural1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports math library
import numpy as np
# Imports plotting library
import matplotlib.pyplot as plt

# %%
# Define a linear function with just one input, x
def linear_function_1D(x,beta,omega):
  y = beta + omega * x

  return y

# %%
 #Plot the 1D linear function

# Define an array of x values from 0 to 10 with increments of 0.01
# https://numpy.org/doc/stable/reference/generated/numpy.arange.html
x = np.arange(0.0,10.0, 0.01)
# Compute y using the function you filled in above
beta = 10.0; omega = 2.0

y = linear_function_1D(x,beta,omega)

# Plot this function
fig, ax = plt.subplots()
ax.plot(x,y,'r-')
ax.set_ylim([0,20]);ax.set_xlim([0,20])
ax.set_xlabel('x'); ax.set_ylabel('y')
plt.show

# TODO -- experiment with changing the values of beta and omega
# to understand what they do.  Try to make a line
# that crosses the y-axis at y=10 and the x-axis at x=5
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Code to draw 2D function -- read it so you know what is going on, but you don't have to change it
def draw_2D_function(x1_mesh, x2_mesh, y):
    fig, ax = plt.subplots()
    fig.set_size_inches(7,7)
    pos = ax.contourf(x1_mesh, x2_mesh, y, levels=256 ,cmap = 'hot', vmin=-10,vmax=10.0)
    fig.colorbar(pos, ax=ax)
    ax.set_xlabel('x1');ax.set_ylabel('x2')
    levels = np.arange(-10,10,1.0)
    ax.contour(x1_mesh, x2_mesh, y, levels, cmap='winter')
    plt.show

# %%
# Define a linear function with two inputs, x1 and x2
def linear_function_2D(x1,x2,beta,omega1,omega2):
  # TODO -- replace the code line below with formula for 2D linear equation
   y = beta + omega1 * x1 + omega2 * x2
   return y

# %%
# Make 2D array of x and y points
x1 = np.arange(0.0, 10.0, 0.1)
x2 = np.arange(0.0, 10.0, 0.1)
x1,x2 = np.meshgrid(x1,x2)  # https://www.geeksforgeeks.org/numpy-meshgrid-function/

# Compute the 2D function for given values of omega1, omega2
beta = -5; omega1 = 1.0; omega2 = -0.5
y  = linear_function_2D(x1,x2,beta, omega1, omega2)

# Draw the function.
# Color represents y value (brighter = higher value)
# Black = -10 or less, White = +10 or more
# 0 = mid orange
# Lines are contours where value is equal
draw_2D_function(x1,x2,y)

# TODO
# Predict what this plot will look like if you set omega_1 to zero
# Change the code and see if you are right.

# TODO
# Predict what this plot will look like if you set omega_2 to zero
# Change the code and see if you are right.

# TODO
# Predict what this plot will look like if you set beta to -5
# Change the code and see if you are correct

# %%
# Define a linear function with three inputs, x1, x2, and x_3
def linear_function_3D(x1,x2,x3,beta,omega1,omega2,omega3):
  # TODO -- replace the code below with formula for a single 3D linear equation
   y = beta + omega1 * x1 + omega2 * x2 + omega3 * x3
   return y

# %%
import numpy as np

# Define the parameters
beta1 = 0.5
beta2 = 0.2
omega11 = -1.0
omega12 = 0.4
omega13 = -0.3
omega21 = 0.1
omega22 = 0.1
omega23 = 1.2

# Define the inputs
x1 = 4
x2 = -1
x3 = 2

# Assuming linear_function_3D is defined somewhere
def linear_function_3D(x1, x2, x3, beta, omega1, omega2, omega3):
    return beta + omega1 * x1 + omega2 * x2 + omega3 * x3

# Compute using the individual equations
y1 = linear_function_3D(x1, x2, x3, beta1, omega11, omega12, omega13)
y2 = linear_function_3D(x1, x2, x3, beta2, omega21, omega22, omega23)

print("Individual equations")
print('y1 = %3.3f\ny2 = %3.3f' % (y1, y2))

# Define vectors and matrices
beta_vec = np.array([[beta1], [beta2]])
omega_mat = np.array([[omega11, omega12, omega13], [omega21, omega22, omega23]])
x_vec = np.array([[x1], [x2], [x3]])

# Compute with vector/matrix form
y_vec = beta_vec + np.matmul(omega_mat, x_vec)

print("Matrix/vector form")
print('y1 = %3.3f\ny2 = %3.3f' % (y_vec[0, 0], y_vec[1, 0]))
# Out:
# Individual equations
# y1 = -4.500
# y2 = 2.900
# Matrix/vector form
# y1 = -4.500
# y2 = 2.900

# %%
# Draw the exponential function

# Define an array of x values from -5 to 5 with increments of 0.01
x = np.arange(-5.0,5.0, 0.01)
y = np.exp(x) ;

# Plot this function
fig, ax = plt.subplots()
ax.plot(x,y,'r-')
ax.set_ylim([0,100]);ax.set_xlim([-5,5])
ax.set_xlabel('x'); ax.set_ylabel('exp[x]')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# exp[0]: This corresponds to the value of
# �
# 0
# e
# 0
#  , which is 1.
#
# exp[1]: This corresponds to the value of
# �
# 1
# e
# 1
#  , which is approximately 2.71828.
#
# exp(+infinity): As
# �
# x approaches positive infinity,
# �
# �
# e
# x
#   also approaches infinity. In the plot, you'll see the exponential function rising toward infinity as
# �
# x increases.
#
# exp(-infinity): As
# �
# x approaches negative infinity,
# �
# �
# e
# x
#   approaches 0. In the plot, you'll see the exponential function rapidly decreasing toward 0 as
# �
# x becomes more negative.

# %%
result_at_origin = linear_function_3D(0, 0, 0, beta, omega1, omega2, omega3)
print("Value at position (0,0,0):", result_at_origin)
# Out:
# Value at position (0,0,0): -5.0

# %%
import numpy as np

# Define inputs and slopes
x1 = np.array([1, 2, 3])  # Example values for x1
x2 = np.array([4, 5, 6])  # Example values for x2

# Individual equations
def linear_equation_1(x1, x2):
    return 2 * x1 + 3 * x2

def linear_equation_2(x1, x2):
    return -1 * x1 + 4 * x2

def linear_equation_3(x1, x2):
    return 3 * x1 - 2 * x2

# Compute values using individual equations
y1 = linear_equation_1(x1, x2)
y2 = linear_equation_2(x1, x2)
y3 = linear_equation_3(x1, x2)

print("Values using individual equations:")
print("y1:", y1)
print("y2:", y2)
print("y3:", y3)

# Matrix form
coeff_matrix = np.array([[2, 3], [-1, 4], [3, -2]])  # Coefficient matrix
input_matrix = np.column_stack((x1, x2))  # Input matrix

# Compute values using matrix form
y_matrix = np.dot(input_matrix, coeff_matrix.T)

print("\nValues using matrix form:")
print("y_matrix:", y_matrix)
# Out:
# Values using individual equations:
# y1: [14 19 24]
# y2: [15 18 21]
# y3: [-5 -4 -3]
#
# Values using matrix form:
# y_matrix: [[14 15 -5]
#  [19 18 -4]
#  [24 21 -3]]

# %%
import numpy as np

# Compute specified logarithmic expressions
log_0 = np.log(0)  # Undefined
log_1 = np.log(1)  # 0
log_e = np.log(np.e)  # 1
log_minus_1 = np.log(-1)  # Undefined
log_exp_3 = np.log(np.exp(3))  # 3
exp_log_4 = np.exp(np.log(4))  # 4

print("log[0]:", log_0)
print("log[1]:", log_1)
print("log[e]:", log_e)
print("log[-1]:", log_minus_1)
print("log[exp[3]]:", log_exp_3)
print("exp[log[4]]:", exp_log_4)
# Out:
# log[0]: -inf
# log[1]: 0.0
# log[e]: 1.0
# log[-1]: nan
# log[exp[3]]: 3.0
# exp[log[4]]: 4.0
# <ipython-input-24-6d0dcfc868de>:4: RuntimeWarning: divide by zero encountered in log
#   log_0 = np.log(0)  # Undefined
# <ipython-input-24-6d0dcfc868de>:7: RuntimeWarning: invalid value encountered in log
#   log_minus_1 = np.log(-1)  # Undefined
